# %%
import numpy as np
import matplotlib.pyplot as plt


data = np.load("../tests/test.npz")
image = data["image"]
beta = data["beta"]
plt.hist(image.ravel())
# Out:
# (array([1.709e+03, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 2.000e+00, 2.384e+03]),
#  array([-3.76578912e-05,  1.12939782e-01,  2.25917221e-01,  3.38894661e-01,
#          4.51872100e-01,  5.64849540e-01,  6.77826979e-01,  7.90804419e-01,
#          9.03781858e-01,  1.01675930e+00,  1.12973674e+00]),
#  <a list of 10 Patch objects>)

# %%
plt.imshow(image)

# %%
data = np.load("../tests/input_model.npz")
image_nu0 = data["model"][0]
image_nu1 = data["model"][1]

plt.imshow(image_nu0)
plt.colorbar()

# %%
plt.imshow(image_nu1)
plt.colorbar()

# %%
plt.imshow(data["others"])
plt.colorbar()

# %%
plt.hist(image_nu0.ravel())

# %%
plt.hist(np.log(image_nu1.ravel()))
# Out:
# (array([ 40.,  72., 124., 216., 368., 592., 580., 636., 656., 812.]),
#  array([-213.57071291, -191.99313176, -170.4155506 , -148.83796945,
#         -127.26038829, -105.68280714,  -84.10522598,  -62.52764483,
#          -40.95006367,  -19.37248252,    2.20509864]),
#  <a list of 10 Patch objects>)
