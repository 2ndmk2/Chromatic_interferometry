# %%
import numpy as np
import os
import sys
import shutil
from pathlib import Path
from astropy.io import fits
import matplotlib.pyplot as plt
import pandas as pd
folder = "/Users/masatakaaizawa/research/current_research/chromatic_imaging/project_test/sparse_result"
sys.path.insert(0,'../config')
file = os.path.join(folder, "mfreq_solutions.npz")

# %%
clean_data = np.load("/Users/masatakaaizawa/research/current_research/chromatic_imaging/\
project_test/clean_result_and_data/clean_result/I0_alpha_clean.npz")

# %%
clean_alpha = clean_data["alpha"]
clean_image = clean_data["I0"]

# %%
data = np.load(file)
l1_arr = data["log10l1"]
ltsv_arr = data["log10ltsv"]
lalpha_arr = data["log10lalpha"]
images = data["results_image"]
print(np.shape(images))
# Out:
# (36, 2, 512, 512)

# %%
print(lalpha_arr)
print(len(lalpha_arr))
# Out:
# [-3. -1.  1.  3. -3. -1.  1.  3. -3. -1.  1.  3. -3. -1.  1.  3. -3. -1.
#   1.  3. -3. -1.  1.  3. -3. -1.  1.  3. -3. -1.  1.  3. -3. -1.  1.  3.]
# 36

# %%
def func_zero_one(mat):
    return_map = np.zeros(np.shape(mat))
    return_map[mat>0] = 1
    return return_map

def alpha_go_zero_if_image_is_zero(alpha, image):
    alpha_return = np.copy(alpha)
    alpha_return[image ==0] = 0
    
    return alpha_return


for i in range(36):
    print("l1 ", l1_arr[i],", ltsv ", ltsv_arr[i],", lalpha ", lalpha_arr[i])
    #plt.figure(figsize = (10,10))
    fig, (ax1,ax2, ax3, ax4, ax5, ax6) = plt.subplots(1,6, figsize=(60,10))
    ax1.imshow(images[i][1], vmin = 0, vmax = 5)
    ax1.set_title("alpha est", fontsize = 30)
    ax2.imshow(alpha_go_zero_if_image_is_zero(images[i][1],images[i][0]), vmin = 0, vmax = 5)
    ax2.set_title("alpha est (zero if I=0)", fontsize = 30)
    ax3.set_title("clean alpha", fontsize = 30)
    ax3.imshow(clean_alpha , vmin = 0, vmax = 5)
    ax4.set_title("I0 (250GHz)", fontsize = 30)
    ax4.imshow(images[i][0])#, vmin = 0, vmax = 5)
    ax5.set_title("where I0 ==0", fontsize = 30)
    ax5.imshow(func_zero_one(images[i][0]))#, vmin = 0, vmax = 5)
    ax6.imshow(func_zero_one(clean_image))#, vmin = 0, vmax = 5)

    plt.show()
# Out:
# l1  -1.0 , ltsv  0.0 , lalpha  -3.0
# l1  -1.0 , ltsv  0.0 , lalpha  -1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cc2a628a8200> in <module>
#      24     ax6.imshow(func_zero_one(clean_image))#, vmin = 0, vmax = 5)
#      25
# ---> 26     plt.show()
#
# ~/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
def plots_comparison_sum(image_for_plots, titles = None, models_titles = None, width_im = 10, fig_size = (20,20), save_folder = None, file_name = "image"):

    len_fig_side,len_fig_tate, x_len, y_len = np.shape(image_for_plots)

    fig, axs = plt.subplots(len_fig_side, len_fig_tate, figsize=fig_size)
    plt.subplots_adjust(wspace=0.4, hspace=0.4)
    for i_args_mod in range(len_fig_tate):
        vmin_input = np.min(image_for_plots[0][i_args_mod])
        vmax_input = np.max(image_for_plots[0][i_args_mod])
        if i_args_mod == 4:
        	vmin_input -= 1
        	vmax_input += 1

        for i_args_div in range(len_fig_side):

            show_region = image_for_plots[i_args_div][i_args_mod]
            show_region = show_region[int(x_len/2) - width_im:int(x_len/2) + width_im, int(y_len/2) - width_im:int(y_len/2) + width_im]
            pcm = axs[i_args_div][i_args_mod].imshow(image_for_plots[i_args_div][i_args_mod], origin = "lower", vmax = vmax_input, vmin = vmin_input)
            axs[i_args_div, i_args_mod].set_xlim(int(x_len/2) - width_im,int(x_len/2) + width_im)
            axs[i_args_div, i_args_mod].set_ylim(int(y_len/2) - width_im,int(y_len/2) + width_im)
            axs[i_args_div, i_args_mod].set_title(titles[i_args_div] + ":" + models_titles[i_args_mod])
            fig.colorbar(pcm, ax=axs[i_args_div][i_args_mod])

    if save_folder !=None:
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)

        plt.savefig(os.path.join(save_folder, "%s.png" % file_name), dpi = 100, bbox_inches='tight')
        plt.close()
