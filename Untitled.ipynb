# %%
import numpy as np
import matplotlib.pyplot as plt

folder ="/Users/masatakaaizawa/research/current_research/chromatic_imaging/project_X2_256/sparse_result"

data = np.load(folder + "/mfreq_solution_regs.npz")
print(data.files)
image = data["image"]
alpha = data["alpha"]
# Out:
# ['image', 'alpha', 'nu_arr', 'nu0']

# %%
n1, n2, n3, nx, ny = np.shape(image)
for i in range(n1):
    for j in range(n2):
        for k in range(n3):
            plt.imshow(alpha[i,j,k])
            plt.colorbar()
            plt.show()
