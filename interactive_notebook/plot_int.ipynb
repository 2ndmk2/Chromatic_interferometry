# %%
# %matplotlib notebook
from ipywidgets import interact
import matplotlib.pyplot as plt
import numpy as np

file_name = "../../project_512_HD_3freqs/sparse_result/mfreq_solution.npz"
data = np.load(file_name)
print(data.files)
arr_sp_mfreq = data["image"]
fig, ax = plt.subplots()
im = ax.imshow(arr_sp_mfreq, origin = "lower")
fig.colorbar(im)


@interact
def show():
    im.set_array(arr_sp_mfreq)
    im.set_clim(arr_sp_mfreq.min(), arr_sp_mfreq.max())
    fig.canvas.draw_idle()

arr_sp_mfreq_1d = np.ravel(arr_sp_mfreq)
# Out:
# ['image', 'alpha', 'image_nu']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
file_name = "../../project_512_HD_3freqs/for_input/input_model.npz"
data = np.load(file_name)
print(data.files)
arr_input = data["model_nu0"]
fig, ax = plt.subplots()
im = ax.imshow(arr_input, origin = "lower")
fig.colorbar(im)

@interact
def show():
    im.set_array(arr_input)
    im.set_clim(arr_input.min(), arr_input.max())
    fig.canvas.draw_idle()

arr_input_1d = np.ravel(arr_input)
# Out:
# ['model', 'model_nu0', 'alpha', 'nu_arr', 'nu0']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
file_name = "../../project_512_HD_3freqs/sparse_result/mfreq_ind_solution.npz"
data = np.load(file_name)
print(data.files)
arr_sp_ind = data["image"]
fig, ax = plt.subplots()
im = ax.imshow(arr_sp_ind, origin = "lower")
fig.colorbar(im)

@interact
def show():
    im.set_array(arr_sp_ind)
    im.set_clim(arr_sp_ind.min(), arr_sp_ind.max())
    fig.canvas.draw_idle()
arr_sp_ind_1d = np.ravel(arr_sp_ind)
# Out:
# ['image', 'alpha', 'image_nu']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
file_name = "../../project_512_HD_3freqs/clean_result_and_data/clean_result/I0_alpha_clean.npz"
data = np.load(file_name)
print(data.files)
arr_clean = data["I0"]
fig, ax = plt.subplots()
im = ax.imshow(arr_clean, origin = "lower")
fig.colorbar(im)

@interact
def show():
    im.set_array(arr_clean)
    im.set_clim(arr_input.min(), arr_input.max())
    fig.canvas.draw_idle()

arr_clean_1d = np.ravel(arr_clean)
# Out:
# ['I0', 'alpha', 'image_nu']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
fig, ax = plt.subplots()
plt.scatter(arr_input_1d, arr_sp_ind_1d,  s = .2, color="k")
plt.scatter(arr_input_1d, arr_sp_mfreq_1d,  s = .2, color ="r")
plt.scatter( arr_input_1d, arr_clean_1d, s = .2, color="b")



@interact
def show():
    ax.set_xlim(-0.0002, 0.0007)
    ax.set_ylim(-0.0002, 0.0007)
    fig.canvas.draw_idle()
    
flag = arr_input_1d>0.0001
print(np.sum( ( arr_input_1d- arr_sp_mfreq_1d)**2))
print(np.sum( ( arr_input_1d- arr_sp_ind_1d)**2))

print(np.sum( ( arr_input_1d[flag]- arr_sp_mfreq_1d[flag])**2))
print(np.sum( ( arr_input_1d[flag]- arr_sp_ind_1d[flag])**2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# 3.0141703008634545e-06
# 1.271965654543284e-06
# 7.7788360791983e-07
# 8.15182395660433e-07

# %%
fig, ax = plt.subplots()
plt.xlabel("Input Intensity at 250GHz")
plt.ylabel("( estimated - Input) intensity")
plt.scatter(arr_input_1d, arr_sp_ind_1d-arr_input_1d,  s = .2, color="k", label="Independent sp")
plt.scatter(arr_input_1d, arr_sp_mfreq_1d-arr_input_1d,  s = .2, color ="r", label="M-Freq sp")
plt.scatter( arr_input_1d, arr_clean_1d-arr_input_1d, s = .2, color="b", label="CLEAN")
plt.legend()


@interact
def show():
    ax.set_xlim(-0.0002, 0.0007)
    ax.set_ylim(-0.0002, 0.0007)
    fig.canvas.draw_idle()
    
    
flag = arr_input_1d>0.0001
#plt.xlim(0.000, 0.0003)
print(np.sum( ( arr_input_1d- arr_sp_mfreq_1d)**2))
print(np.sum( ( arr_input_1d- arr_sp_ind_1d)**2))

print(np.sum( ( arr_input_1d[flag]- arr_sp_mfreq_1d[flag])**2))
print(np.sum( ( arr_input_1d[flag]- arr_sp_ind_1d[flag])**2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# 3.0141703008634545e-06
# 1.271965654543284e-06
# 7.7788360791983e-07
# 8.15182395660433e-07

# %%
file_name = "../../project_512_HD_3freqs/sparse_result/mfreq_solution.npz"
data = np.load(file_name)
print(data.files)
alpha_sp_mfreq = data["alpha"]
fig, ax = plt.subplots()
im = ax.imshow(alpha_sp_mfreq, origin = "lower")
fig.colorbar(im)


@interact
def show():
    im.set_array(alpha_sp_mfreq)
    im.set_clim(alpha_sp_mfreq.min(), alpha_sp_mfreq.max())
    im.set_clim(2, 4)

    fig.canvas.draw_idle()

alpha_sp_mfreq_1d = np.ravel(alpha_sp_mfreq)
# Out:
# ['image', 'alpha', 'image_nu']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
file_name = "../../project_512_HD_3freqs/clean_result_and_data/clean_result/I0_alpha_clean.npz"
data = np.load(file_name)
print(data.files)
alpha_clean = data["alpha"]
fig, ax = plt.subplots()
im = ax.imshow(alpha_clean, origin = "lower")
fig.colorbar(im)

@interact
def show():
    im.set_array(alpha_clean)
    im.set_clim(-1, 5)
    fig.canvas.draw_idle()

alpha_clean_1d = np.ravel(alpha_clean)
# Out:
# ['I0', 'alpha', 'image_nu']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
file_name = "../../project_512_HD_3freqs/for_input/input_model.npz"
data = np.load(file_name)
print(data.files)
alpha_input = data["alpha"]
fig, ax = plt.subplots()
im = ax.imshow(alpha_input, origin = "lower")
fig.colorbar(im)

@interact
def show():
    im.set_array(alpha_input)
    im.set_clim(alpha_input.min(), alpha_input.max())
    fig.canvas.draw_idle()

alpha_input_1d = np.ravel(alpha_input)
# Out:
# ['model', 'model_nu0', 'alpha', 'nu_arr', 'nu0']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
file_name = "../../project_512_HD_3freqs/sparse_result/mfreq_ind_solution.npz"
data = np.load(file_name)
print(data.files)
alpha_sp_ind = data["alpha"]
fig, ax = plt.subplots()
im = ax.imshow(arr_sp_ind, origin = "lower")
fig.colorbar(im)

@interact
def show():
    im.set_array(alpha_sp_ind)
    im.set_clim(alpha_sp_ind.min(), alpha_sp_ind.max())
    fig.canvas.draw_idle()
alpha_sp_ind_1d = np.ravel(alpha_sp_ind)
# Out:
# ['image', 'alpha', 'image_nu']
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal', adjustable='box')
nx, ny = np.shape(alpha_sp_ind )
for_flag = np.zeros((nx, ny))
wd = 40
for_flag[int(nx/2)-wd:int(nx/2)+wd, int(nx/2)-wd:int(nx/2)+wd] = 1
for_flag = np.ravel(for_flag)
flag = for_flag==1
flag = flag * np.isfinite(alpha_clean_1d)

plt.xlabel("Input alpha")
plt.ylabel("alpha (indepdent sp)")
plt.scatter( alpha_input_1d[flag],alpha_sp_ind_1d[flag], s = .2)
@interact
def show():
    ax.set_xlim(2, 5)
    ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
    
    
fig, ax = plt.subplots()
ax.set_aspect('equal', adjustable='box')
plt.xlabel("Input alpha")
plt.ylabel("alpha (M-freq sp)")
plt.scatter(alpha_input_1d[flag],alpha_sp_mfreq_1d[flag],  s = .2, color ="r")

@interact
def show():
    ax.set_xlim(2, 5)
    ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
    
    
fig, ax = plt.subplots()
ax.set_aspect('equal', adjustable='box')
plt.xlabel("Input alpha")
plt.ylabel("alpha (CLEAN)")
plt.scatter(alpha_input_1d[flag],alpha_clean_1d[flag],  s = .2, color ="r")

@interact
def show():
    ax.set_xlim(2, 5)
    ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
    
print(np.sum( ( alpha_input_1d- alpha_sp_mfreq_1d)**2))
print(np.sum( ( alpha_input_1d- alpha_sp_ind_1d)**2))

print(np.sum( ( alpha_input_1d[flag]- alpha_sp_mfreq_1d[flag])**2))
print(np.sum( ( alpha_input_1d[flag]- alpha_sp_ind_1d[flag])**2))
print(np.sum( ( alpha_input_1d[flag]- alpha_clean_1d[flag])**2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# 1034557.3369848117
# 1040667.5551328253
# 10943.521291318268
# 13369.051049875996
# 9904.732645534184

# %%
fig, ax = plt.subplots()
#ax.set_aspect('equal', adjustable='box')
nx, ny = np.shape(alpha_sp_ind )
for_flag = np.zeros((nx, ny))
wd = 40
for_flag[int(nx/2)-wd:int(nx/2)+wd, int(nx/2)-wd:int(nx/2)+wd] = 1
for_flag = np.ravel(for_flag)
flag = for_flag==1
flag = flag * np.isfinite(alpha_clean_1d)
plt.xlabel("Input alpha")
plt.ylabel("( estimated - Input) alpha")
plt.scatter(alpha_input_1d[flag],alpha_clean_1d[flag] - alpha_input_1d[flag],  s = .5, color="b", label="CLEAN")
plt.scatter(alpha_input_1d[flag],alpha_sp_mfreq_1d[flag] - alpha_input_1d[flag],  s = .5, color ="r", label="M-Freq sp")
#plt.scatter( alpha_input_1d[flag],alpha_sp_ind_1d[flag] - alpha_input_1d[flag], s = .5, color="k", label="Independent sp")




@interact
def show():
    #ax.set_xlim(2, 5)
    ax.set_ylim(-3, 3)
    fig.canvas.draw_idle()
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
fig, ax = plt.subplots()
#ax.set_aspect('equal', adjustable='box')
plt.xlabel("alpha")
plt.ylabel("intensity")
plt.scatter(alpha_input_1d[flag],arr_input_1d[flag],  s = .2, color ="b", label="input")
plt.scatter(alpha_sp_mfreq_1d[flag],arr_sp_mfreq_1d[flag],  s = .9, color ="r", label="M-freq sp")
@interact
def show():
    ax.set_xlim(1, 5)

    #ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
"""
plt.scatter(alpha_sp_ind_1d[flag],arr_sp_ind_1d[flag],  s = .2, color ="k")
@interact
def show():
    ax.set_xlim(1, 5)
    #ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
"""
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
fig, ax = plt.subplots()
#ax.set_aspect('equal', adjustable='box')
plt.scatter(alpha_input_1d[flag],arr_input_1d[flag],  s = .2, color ="b", label="input")
plt.xlabel("alpha")
plt.ylabel("intensity")
plt.scatter(alpha_clean_1d[flag],arr_clean_1d[flag],  s = .9, color ="r", label="clean")
@interact
def show():
    ax.set_xlim(1, 5)

    #ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
"""
plt.scatter(alpha_sp_ind_1d[flag],arr_sp_ind_1d[flag],  s = .2, color ="k")
@interact
def show():
    ax.set_xlim(1, 5)
    #ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
"""
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
fig, ax = plt.subplots()
#ax.set_aspect('equal', adjustable='box')
plt.scatter(alpha_input_1d[flag],arr_input_1d[flag],  s = .2, color ="b", label="input")
@interact
def show():
    #ax.set_xlim(2, 5)
    #ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
    
plt.xlabel("alpha")
plt.ylabel("intensity")
plt.scatter(alpha_sp_ind_1d[flag],arr_sp_ind_1d[flag],  s = .2, color ="k", label="independent sp")
plt.legend()
@interact
def show():
    ax.set_xlim(1, 5)
    #ax.set_ylim(2, 5)
    fig.canvas.draw_idle()
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
